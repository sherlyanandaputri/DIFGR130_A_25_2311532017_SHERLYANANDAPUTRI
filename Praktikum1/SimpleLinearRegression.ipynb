# %% [markdown]
# <a href="https://colab.research.google.com/github/sherlyanandaputri/DIFGR130_A_25_2311532017_SHERLYANANDAPUTRI/blob/main/Praktikum1/SimpleLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {'luas' : [6, 8, 10, 14, 18],
        'harga' : [7, 9, 13, 17.5, 18]}

df = pd.DataFrame(data)
df
# Out:
#    luas  harga
# 0     6    7.0
# 1     8    9.0
# 2    10   13.0
# 3    14   17.5
# 4    18   18.0

# %%
import matplotlib.pyplot as plt

df.plot(kind='scatter', x= 'luas', y='harga')
plt.title('perbandingan luas tanah dengan harga tanah')
plt.xlabel('luas tanah(m persegi)')
plt.ylabel('harga tanah(dollar)')
plt.xlim(0, 25)
plt.ylim(0, 25)
plt.grid(True)
plt.show()

# %%
import numpy as np

X=np.array(df['luas'])    #Independent Variable (Features)
y=np.array(df['harga'])   #Dependent Variable (Target)

print(f'X: {X}')
print(f'y: {y}')
# Out:
# X: [ 6  8 10 14 18]
# y: [ 7.   9.  13.  17.5 18. ]

# %%
X = X.reshape(-1, 1)

print(f'X shape: {X.shape}')
print(f'X: {X}')
# Out:
# X shape: (5, 1)
# X: [[ 6]
#  [ 8]
#  [10]
#  [14]
#  [18]]

# %% [markdown]
# MOdeling

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
X_vis = np.array([0,25]).reshape(-1, 1)
y_vis = model.predict(X_vis)

# %%
plt.scatter(X, y)
plt.plot(X_vis, y_vis, color='red')

plt.title('Perbandingan luas tanah dengan harga tanah')
# Out:
# Text(0.5, 1.0, 'Perbandingan luas tanah dengan harga tanah')

# %%
luas_tanah = np.array([12, 15, 20]).reshape(-1, 1)
print(luas_tanah.shape)
luas_tanah
# Out:
# (3, 1)
# array([[12],
#        [15],
#        [20]])

# %%
harga_prediksi = model.predict(luas_tanah)
harga_prediksi
# Out:
# array([13.68103448, 16.60991379, 21.49137931])

# %%
for luas, hrg in zip(luas_tanah, harga_prediksi):
  print(f'Luas tanah {luas}: harga prediksi: {hrg}')
# Out:
# Luas tanah [12]: harga prediksi: 13.681034482758621
# Luas tanah [15]: harga prediksi: 16.609913793103445
# Luas tanah [20]: harga prediksi: 21.491379310344826

# %% [markdown]
# Evaluasi Simple Linear Regressiom Model

# %% [markdown]
# Training & Testing Dataset

# %%
X_train = np.array([6, 8, 10, 14, 18]).reshape(-1, 1)
y_train = np.array([7, 9, 13, 17.5, 18])

X_test = np.array([9, 9, 11, 16, 12]).reshape(-1, 1)
y_test = np.array([11, 8.5, 15, 18, 11])

# %% [markdown]
# Training Simple Linear Regression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

y_pred = model.predict(X_test)
r_squared = r2_score(y_test, y_pred)
print(f'R-squared: {r_squared}')
# Out:
# R-squared: 0.6873061136400747

# %%
y_pred
# Out:
# array([10.75215517, 10.75215517, 12.70474138, 17.5862069 , 13.68103448])

# %%
y_test
# Out:
# array([11. ,  8.5, 15. , 18. , 11. ])
